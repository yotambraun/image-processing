# %%
import math
import sys
from PIL import Image, ImageFilter

# %%
image = Image.open("/content/image.jpg")

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=630x472 at 0x7F08EA30EFD0>

# %%
#use Kernel of edge detections with convulotions 
filterd = image.filter(ImageFilter.Kernel(
    size = (3,3),
    kernel = [-1,-1,-1,-1,8,-1,-1,-1,-1],
    scale=1
    
))

# %%
filterd
# Out:
# <PIL.Image.Image image mode=RGB size=630x472 at 0x7F08EBCA4750>

# %%
immax = image.filter(ImageFilter.MaxFilter(size = 3))

# %%
immax
# Out:
# <PIL.Image.Image image mode=RGB size=630x472 at 0x7F08EA3A3F90>

# %%
immin = image.filter(ImageFilter.MinFilter(size = 3))

# %%
immin
# Out:
# <PIL.Image.Image image mode=RGB size=630x472 at 0x7F08EA36F9D0>

# %%
# Out:
#   File "<ipython-input-29-536bca3ff9ac>", line 1
#     git clone https://github.com/alievk/avatarify.git
#             ^
# SyntaxError: invalid syntax
